# %% [markdown]
# <a href="https://colab.research.google.com/github/Yoki198/colab/blob/main/%E2%80%9CUntitled0_ipynb%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #一级标题
# **噶客户尽快**`ctrl`

# %%
a = 10

# %% [markdown]
# ##二级标题

# %%
print (a)
# Out:
# 10

# %% [markdown]
# ###三级标题

# %%
print (a+10)
import numpy
# Out:
# 20
